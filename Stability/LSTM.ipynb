# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import glob
import os, sys
import inspect
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, current_dir) 
sys.path.insert(0, parent_dir) 

from utils import *
from rnn_models import LSTM

# %%
sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 1})
fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
labels = ['Identity', 'BLAIZ']

exp_list = glob.glob(parent_dir+r"\\experiments\\copy_memory\\lstm\search\*")
v2_losses = np.zeros((len(exp_list), 100000))
for i,exp in enumerate(exp_list):
        learn_path = glob.glob(exp+'\learning*')[0]
        with open(learn_path, 'rb') as handle:
            learning_info = pickle.load(handle)
        # v2_losses[i, :] = learning_info['training_loss']
        ax.plot(learning_info['training_loss'])

# ax.errorbar(range(500), np.mean(v3_losses, axis=0), np.percentile(v3_losses, q=50, axis=0), color='blue', ecolor='blue', label='BLA')

ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_yscale("log")

# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.17),
#           fancybox=True, shadow=True, ncol=2, columnspacing=0.8, handletextpad=.3)
# plt.savefig(current_dir+"//figures/loss_lstm.pdf", bbox_inches="tight")
# plt.savefig(current_dir+"//figures/loss_lstm.png", bbox_inches="tight")

# %%
sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 1})
fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
labels = ['Identity', 'BLAIZ']

exp_list = glob.glob(parent_dir+r"\\experiments\\copy_memory\\blas\search\*")


v2_losses = np.zeros((len(exp_list), 100000))
for i,exp in enumerate(exp_list):
        print(exp)
        learn_path = glob.glob(exp+'\learning*')[0]
        with open(learn_path, 'rb') as handle:
            learning_info = pickle.load(handle)
        # v2_losses[i, :] = learning_info['training_loss']
        with open(exp + '\\training_kwargs.pickle', 'rb') as handle:
            training_kwargs = pickle.load(handle)
        ax.plot(learning_info['training_loss'], label=training_kwargs['scheduler_step_size'])
# ax.errorbar(range(500), np.mean(v3_losses, axis=0), np.percentile(v3_losses, q=50, axis=0), color='blue', ecolor='blue', label='BLA')

ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_yscale("log")

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.17),
          fancybox=True, shadow=True, ncol=2, columnspacing=0.8, handletextpad=.3)
# plt.savefig(current_dir+"//figures/loss_lstm.pdf", bbox_inches="tight")
# plt.savefig(current_dir+"//figures/loss_lstm.png", bbox_inches="tight")
# Out:
# C:\Users\abel_\Documents\Rotations\CIT\cit_for_computation\\experiments\\copy_memory\\blas\search\exp_delay4_mse_sgd_blas_idx10_1684029962
# C:\Users\abel_\Documents\Rotations\CIT\cit_for_computation\\experiments\\copy_memory\\blas\search\exp_delay4_mse_sgd_blas_idx1_1684018083
# C:\Users\abel_\Documents\Rotations\CIT\cit_for_computation\\experiments\\copy_memory\\blas\search\exp_delay4_mse_sgd_blas_idx2_1684019625
# C:\Users\abel_\Documents\Rotations\CIT\cit_for_computation\\experiments\\copy_memory\\blas\search\exp_delay4_mse_sgd_blas_idx3_1684021184
# C:\Users\abel_\Documents\Rotations\CIT\cit_for_computation\\experiments\\copy_memory\\blas\search\exp_delay4_mse_sgd_blas_idx4_1684022721
# C:\Users\abel_\Documents\Rotations\CIT\cit_for_computation\\experiments\\copy_memory\\blas\search\exp_delay4_mse_sgd_blas_idx5_1684024315
# C:\Users\abel_\Documents\Rotations\CIT\cit_for_computation\\experiments\\copy_memory\\blas\search\exp_delay4_mse_sgd_blas_idx6_1684025867
# ...

# %%
# Out:
# 2
